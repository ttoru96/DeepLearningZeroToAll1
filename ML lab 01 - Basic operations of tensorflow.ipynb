# %% [markdown]
# ## Hello TensorFlow!

# %%
import tensorflow as tf

# Create a constant op
# This op is added as a node to the default graph
hello = tf.constant("Hello, TensorFlow!")

# start a TF session
sess = tf.Session()

# run the operation and get result
print(sess.run(hello))
# Out:
# /Users/juliejung/ml/env/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /Users/juliejung/ml/env/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /Users/juliejung/ml/env/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# ...

# %% [markdown]
# ## Building Computation Graph

# %%
# 1. Build graph(tensors) using Tensorflow operations
node1 = tf.constant(3.0, tf.float32)
node2 = tf.constant(4.0) # also tf.float32 implicitly
node3 = tf.add(node1, node2)

# 2. feed data and run graph using session
sess = tf.Session()
print("sess.run(node1, node2): ", sess.run([node1, node2]))
print("sess.run(node3): ", sess.run(node3))

# 3. update variables in the graph (which means that it return values)
# Out:
# sess.run(node1, node2):  [3.0, 4.0]
# sess.run(node3):  7.0

# %% [markdown]
# ## Placeholder is a special node which is distinguished from constant node in that placeholder gets the input for node on execution.

# %%
import tensorflow as tf

a = tf.placeholder(tf.float32)
b = tf.placeholder(tf.float32)
adder_node = a + b # + provides a shortcut for tf.add

sess = tf.Session()

print(sess.run(adder_node, feed_dict={a: 3, b: 4.5}))
print(sess.run(adder_node, feed_dict={a:[1,3], b:[2,4]}))
# Out:
# 7.5
# [3. 7.]

# %% [markdown]
# ## Everything is Tensor
# ### Tensor is basically an array

# %%
3 # rank 0 tensor; thi sis a scalar with shape []
[1, 2, 3] # rank 1 tensor; this is a vector with shape[3]
[[1, 2, 3], [4, 5, 6]] # rank 2 tensor; a matrix with shape [2, 3]

# rank는 차원
# shape은 배열의 모양 eg. A 3-D tensor with shape [1, 4, 3]
# type: 대부분의 경우 float 32를 사용한다고 한다
